# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %%
df_pre = pd.read_csv(
    "preprocessed_post_arrival.csv"
)

df_pre.head()
# Out:
#      5. How often do you feel overwhelmed by your responsibilities abroad?    \
# 0                                          -0.480185
# 1                                          -1.322957
# 2                                           1.205361
# 3                                           1.205361
# 4                                          -0.480185
#
#    6.How often do you feel nervous or on edge since arriving abroad?    \
# 0                                           0.760251
# 1                                          -1.315355
# 2                                           0.760251
# 3                                           0.760251
# 4                                          -1.315355
#
#      8. How often do you feel low energy or lack motivation due to stress?     \
# 0                                           1.041923
# 1                                          -1.494078
# 2                                           1.041923
# 3                                           0.196589
# 4                                          -0.648745
#
#     9. How often do you struggle with concentration because of mental pressure?    \
# 0                                           0.541510
# 1                                          -1.846688
# 2                                           0.541510
# 3                                           0.541510
# 4                                           0.541510
#
#    10. How confident are you in handling emotional ups and downs abroad?    \
# 0                                          -0.230171
# 1                                           1.089475
# 2                                          -1.549816
# 3                                           1.089475
# 4                                          -0.230171
#
#     11. How difficult was cultural adjustment after arriving?    \
# 0                                           0.620922
# 1                                          -1.179054
# 2                                           1.220914
# 3                                          -1.179054
# 4                                           0.620922
#
#     12. How often do you feel socially isolated or lonely abroad?    \
# 0                                           1.658987
# 1                                          -1.145394
# 2                                           0.957892
# 3                                          -0.444299
# 4                                          -0.444299
#
#      13. How confident are you in communicating with people in your new country?    \
# 0                                          -1.636062
# 1                                           1.285073
# 2                                           0.311361
# 3                                          -0.662350
# 4                                           0.311361
#
#     14. Do you feel accepted by classmates, peers, or community members?    \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#     15. How concerned are you about finding and maintaining friendships abroad?    \
# 0                                          -1.960294
# 1                                           0.905178
# 2                                          -0.049979
# 3                                           0.905178
# 4                                          -0.049979
#
#    ...    4. Country you are currently studying in.  _Sweeden  \
# 0  ...                                              False
# 1  ...                                              False
# 2  ...                                              False
# 3  ...                                              False
# 4  ...                                               True
#
#      4. Country you are currently studying in.  _USA  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#      4. Country you are currently studying in.  _usa  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#      7.  How difficult is it for you to relax after your daily activities while living abroad? _2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#      7.  How difficult is it for you to relax after your daily activities while living abroad? _3  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#      7.  How difficult is it for you to relax after your daily activities while living abroad? _4  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#      7.  How difficult is it for you to relax after your daily activities while living abroad? _Yes  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#      19. How often do you feel stressed before exams or deadlines?   _Often  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#      19. How often do you feel stressed before exams or deadlines?   _Rarely  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#      19. How often do you feel stressed before exams or deadlines?   _Sometimes
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
# [5 rows x 50 columns]

# %%
depression_cols_pre = [
    '9. How often do you feel low energy or lack motivation due to pre-departure stress?',
    '10. How confident do you feel in handling emotional ups and downs during this transition?',
    '12. How often do you overthink potential problems that might happen abroad?',
    '14. How stressed do you feel about adapting to a new cultural and academic environment?',
    '15. How satisfied are you with your current academic performance?',
    '16. Do you feel pressure to perform well academically abroad? ',
    '18. How confident are you in finding part-time work or financial support abroad?',
    '19. How often do you feel emotionally exhausted during pre-departure preparations?',
    '20. How often do you feel mentally drained or burnt out due to expectations and planning?'
]

# %%
reverse_cols = [
    '10. How confident do you feel in handling emotional ups and downs during this transition?',
    '15. How satisfied are you with your current academic performance?',
    '18. How confident are you in finding part-time work or financial support abroad?'
]

for col in reverse_cols:
    df_pre[col] = 6 - df_pre[col]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '10. How confident do you feel in handling emotional ups and downs during this transition?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 8
#       1 reverse_cols = [
#       2     '10. How confident do you feel in handling emotional ups and downs during this transition?',
#       3     '15. How satisfied are you with your current academic performance?',
#       4     '18. How confident are you in finding part-time work or financial support abroad?'
#       5 ]
#       7 for col in reverse_cols:
# ----> 8     df_pre[col] = 6 - df_pre[col]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '10. How confident do you feel in handling emotional ups and downs during this transition?'
