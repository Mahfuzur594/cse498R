# %%
import pandas as pd

df = pd.read_csv("pre_departure_ml_ready.csv")
df.head()
# Out:
#    5. How often do you feel overwhelmed by your responsibilities during pre departure preparation?  \
# 0                                          -0.037697
# 1                                          -0.037697
# 2                                          -0.037697
# 3                                          -0.037697
# 4                                           0.823524
#
#    6. How often do you feel nervous or on edge about going abroad?  \
# 0                                          -0.008484
# 1                                          -0.008484
# 2                                          -0.008484
# 3                                          -1.688382
# 4                                           0.831464
#
#    7. Do you find it difficult to relax when thinking about your upcoming move?  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# ...

# %%
df['Depression_Level'].value_counts().sort_index()
# Out:
# Depression_Level
# 0    297
# Name: count, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# bool       44
# float64    21
# int64       6
# Name: count, dtype: int64

# %%
# Check column names
df.columns

# Check data types
df.dtypes

# Check missing values
df.isnull().sum()
# Out:
# 5. How often do you feel overwhelmed by your responsibilities during pre departure preparation?    0
# 6. How often do you feel nervous or on edge about going abroad?                                    0
# 7. Do you find it difficult to relax when thinking about your upcoming move?                       0
# 8. How often do you worry about your ability to cope with challenges abroad?                       0
# 9. How often do you feel low energy or lack motivation due to pre departure stress?                0
#                                                                                                   ..
# Destination Country_United States                                                                  0
# Destination Country_Usa                                                                            0
# Destination Country_lithunia                                                                       0
# ...
