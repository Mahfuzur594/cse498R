# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %%
df_pre = pd.read_csv(
    "preprocessed_pre_departure.csv"
)

df_pre.head()
# Out:
#    5. How often do you feel overwhelmed by your responsibilities during pre‑departure preparation?  \
# 0                                          -0.037697
# 1                                          -0.037697
# 2                                          -0.037697
# 3                                          -0.037697
# 4                                           0.823524
#
#    6. How often do you feel nervous or on edge about going abroad?  \
# 0                                          -0.008484
# 1                                          -0.008484
# 2                                          -0.008484
# 3                                          -1.688382
# 4                                           0.831464
#
#    7. Do you find it difficult to relax when thinking about your upcoming move?  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    8. How often do you worry about your ability to cope with challenges abroad?  \
# 0                                           0.730317
# 1                                          -0.750257
# 2                                          -0.009970
# 3                                          -1.490544
# 4                                          -1.490544
#
#    9. How often do you feel low energy or lack motivation due to pre‑departure stress?  \
# 0                                           1.613371
# 1                                          -0.091865
# 2                                           0.760753
# 3                                          -1.797100
# 4                                           0.760753
#
#    10. How confident do you feel in handling emotional ups and downs during this transition?  \
# 0                                          -0.016200
# 1                                          -0.016200
# 2                                          -0.016200
# 3                                           0.785689
# 4                                           0.785689
#
#    11. How anxious are you about visa delays or possible rejection?  \
# 0                                           1.030574
# 1                                          -1.080326
# 2                                           0.326941
# 3                                          -1.080326
# 4                                           1.030574
#
#    12. How often do you overthink potential problems that might happen abroad?  \
# 0                                           0.585081
# 1                                          -0.230736
# 2                                           0.585081
# 3                                           1.400898
# 4                                           0.585081
#
#    13. How confident are you in your English/language communication skills?  \
# 0                                          -1.285980
# 1                                          -1.285980
# 2                                          -0.347562
# 3                                           1.529274
# 4                                           0.590856
#
#    14. How stressed do you feel about adapting to a new cultural and academic environment?  \
# 0                                          -0.156804
# 1                                          -0.156804
# 2                                           0.674819
# 3                                          -1.820050
# 4                                           0.674819
#
#    ...  Destination Country_New Zealand   Destination Country_South Korea   \
# 0  ...                             False                             False
# 1  ...                             False                             False
# 2  ...                             False                             False
# 3  ...                             False                             False
# 4  ...                             False                             False
#
#    Destination Country_Switzerland   \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    Destination Country_UK/ Australia, Netherlands   Destination Country_USA  \
# 0                                            False                     True
# 1                                            False                    False
# 2                                            False                    False
# 3                                            False                    False
# 4                                            False                     True
#
#    Destination Country_Uk  Destination Country_United States   \
# 0                   False                               False
# 1                   False                               False
# 2                   False                               False
# 3                   False                               False
# 4                   False                               False
#
#    Destination Country_Usa  Destination Country_lithunia  \
# 0                    False                         False
# 1                    False                         False
# 2                    False                         False
# 3                    False                         False
# 4                    False                         False
#
#    Destination Country_usa
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
#
# [5 rows x 70 columns]

# %%
depression_cols_pre = [
    '9. How often do you feel low energy or lack motivation due to pre-departure stress?',
    '10. How confident do you feel in handling emotional ups and downs during this transition?',
    '12. How often do you overthink potential problems that might happen abroad?',
    '14. How stressed do you feel about adapting to a new cultural and academic environment?',
    '15. How satisfied are you with your current academic performance?',
    '16. Do you feel pressure to perform well academically abroad?',
    '18. How confident are you in finding part-time work or financial support abroad?',
    '19. How often do you feel emotionally exhausted during pre-departure preparations?',
    '20. How often do you feel mentally drained or burnt out due to expectations and planning?'
]

# %%
missing = [col for col in depression_cols_pre if col not in df.columns]
print("Missing columns:", missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 missing = [col for col in depression_cols_pre if col not in df.columns]
#       2 print("Missing columns:", missing)
#
# NameError: name 'df' is not defined

# %%
reverse_cols = [
    '10. How confident do you feel in handling emotional ups and downs during this transition?',
    '15. How satisfied are you with your current academic performance?',
    '18. How confident are you in finding part-time work or financial support abroad?'
]

for col in reverse_cols:
    df_pre[col] = 6 - df_pre[col]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '18. How confident are you in finding part-time work or financial support abroad?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       1 reverse_cols = [
#       2     '10. How confident do you feel in handling emotional ups and downs during this transition?',
#       3     '15. How satisfied are you with your current academic performance?',
#       4     '18. How confident are you in finding part-time work or financial support abroad?'
#       5 ]
#       7 for col in reverse_cols:
# ----> 8     df_pre[col] = 6 - df_pre[col]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '18. How confident are you in finding part-time work or financial support abroad?'
