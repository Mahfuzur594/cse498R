# %%
import pandas as pd

# %%
df_pre = pd.read_csv("preprocessed_pre_departure.csv")
df_pre.head()
# Out:
#    5. How often do you feel overwhelmed by your responsibilities during pre‑departure preparation?  \
# 0                                          -0.037697
# 1                                          -0.037697
# 2                                          -0.037697
# 3                                          -0.037697
# 4                                           0.823524
#
#    6. How often do you feel nervous or on edge about going abroad?  \
# 0                                          -0.008484
# 1                                          -0.008484
# 2                                          -0.008484
# 3                                          -1.688382
# 4                                           0.831464
#
#    7. Do you find it difficult to relax when thinking about your upcoming move?  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# ...

# %%
df_target = pd.read_csv("pre_departure_target.csv")
df_target.head()
# Out:
#    Depression_Level
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
print("Preprocessed rows:", df_pre.shape[0])
print("Target rows:", df_target.shape[0])
# Out:
# Preprocessed rows: 297
# Target rows: 302

# %%
df_pre['Depression_Level'] = df_target['Depression_Level']

# %%
df_pre.head()
# Out:
#    5. How often do you feel overwhelmed by your responsibilities during pre‑departure preparation?  \
# 0                                          -0.037697
# 1                                          -0.037697
# 2                                          -0.037697
# 3                                          -0.037697
# 4                                           0.823524
#
#    6. How often do you feel nervous or on edge about going abroad?  \
# 0                                          -0.008484
# 1                                          -0.008484
# 2                                          -0.008484
# 3                                          -1.688382
# 4                                           0.831464
#
#    7. Do you find it difficult to relax when thinking about your upcoming move?  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# ...

# %%
df_pre['Depression_Level'].value_counts().sort_index()
# Out:
# Depression_Level
# 0    297
# Name: count, dtype: int64

# %%
df_pre.to_csv(
    "pre_departure_ml_ready.csv",
    index=False
)
