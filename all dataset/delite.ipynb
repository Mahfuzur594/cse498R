# %%
import pandas as pd

df = pd.read_csv("POST-ARRIVAL_STUDENT_MENTAL_HEALTH_SURVEY_EXTENDED.csv")

# %%
df.drop(df.index[148:176], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv("dataset.csv", index=False)
